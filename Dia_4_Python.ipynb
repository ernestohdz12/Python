# %% [markdown]
# # Temario
# - Funciones
# - Funciones lambda
# - Errores (excepciones)

# %% [markdown]
# ## Funciones
# En este curso hemos usado algunas funciones integradas python, pero tambien nosotros podemos definir funciones, siendo estas un bloque de codigo reutilizable que podemos mandar a llamar varias veces en el codigo

# %%
def mensaje ():
  print("Hola Mundo")
mensaje()
# Out:
# Hola Mundo

# %%
# Funcion con retorno
def mensaje ():
  return "Hola Mundo"
print(mensaje())
va = mensaje()
print(va)
# Out:
# Hola Mundo
# Hola Mundo

# %%
def saludo(nombre):
  print("Hola", nombre, "!!!")
tuNombre = input("Ingresa tu nombre: ")
saludo(tuNombre)
# Nota: El nombre de la variable del parametro puede o no ser el mismo fuera de la funcion
# Out:
# Ingresa tu nombre: Hallo
# Hola Hallo !!!

# %%
# Puedes mandar el parametro de esta manera
saludo("Grupo")
# Out:
# Hola Grupo !!!

# %%
def suma(numero_1, numero_2):
  return numero_1 + numero_2
print(suma(1, 5))
# Out:
# 6

# %%
def bienvenida(nombre = "invitado"):
  print("Hola", nombre)
bienvenida()
bienvenida("Victor")
# Out:
# Hola invitado
# Hola Victor

# %%
def suma(numero_1 = 2, numero_2 = 10): #Podemos poner tantos parametros como queramos
  return numero_1 + numero_2
suma = suma(10000, 15345252)
print(suma)
# Out:
# 15355252

# %%
# Descuento
def descuento(precio, desc = 0.15):
  precio = precio * (1 - desc)
  print("El nuevo precio es: ", precio)
descuento(750)
descuento(800,0.25)
# Out:
# El nuevo precio es:  637.5
# El nuevo precio es:  600.0

# %%
def usuario(nombre,edad):
  return(nombre,edad)
persona = usuario("Victor", 21)
print(type(persona))
print(persona)
# Out:
# <class 'tuple'>
# ('Victor', 21)

# %%
def operaciones(numero):
  doble = numero * 2
  triple = numero * 3
  cuadruple = numero * 4
  quintuple = numero * 5
  return doble, triple, cuadruple, quintuple
resultado = operaciones(2)
print(resultado)
# Out:
# (4, 6, 8, 10)

# %%
def saludar(nombre):
  return f"Hola, {nombre}!"

def despedirse(nombre):
  return f"Adiós, {nombre}!"

def mensaje_completo(nombre):
  saludo = saludar(nombre)
  despedida = despedirse(nombre)
  return saludo + "\n" + despedida

print(mensaje_completo("Anne"))
# Out:
# Hola, Anne!
# Adiós, Anne!

# %%
# Ahora supongamos que tenemos una heladeria
def pedir_sabor():
  sabores = ["vainilla","chocolate","fresa"]
  print("Sabores disponibles", ",", sabores)
  sabor = input("Elige un sabor: ").strip().lower()
  # lower hace minusculas las palabras
  # strip() elimina los espacios antes y despues
  # si sabor no esta en sabores
  while sabor not in sabores:
    sabor = input("Elige un sabor (nuevamente): ").strip().lower()
  return sabor

def pedir_cantidad():
  cantidad = int(input("Cuantas bolas de nieve?: "))
  while cantidad <= 0:
    cantidad = int(input("Cuantas bolas de nieve? (ingresa un valor valido): "))
  return cantidad

# Funcion madre, llama a otras funciones
def pedir_helado():
  sabor = pedir_sabor()
  cant = pedir_cantidad()
  print(f"Pedido: {cant} bola(s) de helado {sabor}")
  return cant, sabor

total_pedidos = int(input("Cuantos clientes atenderas? :"))
for i in range(total_pedidos):
  pedir_helado()
# Out:
# Cuantos clientes atenderas? :2
# Sabores disponibles , ['vainilla', 'chocolate', 'fresa']
# Elige un sabor: vainilla
# Cuantas bolas de nieve?: 2
# Pedido: 2 bola(s) de helado vainilla
# Sabores disponibles , ['vainilla', 'chocolate', 'fresa']
# Elige un sabor: fresa
# Cuantas bolas de nieve?: 3
# Pedido: 3 bola(s) de helado fresa

# %% [markdown]
# ## Funciones lambda
# Una funcion lambda es una funcion acortada para escribir una funcion de esta forma
# nombreFuncion = lambda parametros: accion
# La diferencia entre las funciones lambda y las funciones normales es que suelen ser un poco mas limitadas

# %%
sumar = lambda x,y : x + y
print(sumar(2,3))
# Out:
# 5

# %%
descuentoLambda = lambda desc, precio: ((precio * (1-desc)), (precio * desc))
nuevoPrecio = descuentoLambda(0.4,500)
print("El precio a pagar es", nuevoPrecio[0])
# Out:
# El precio a pagar es 300.0

# %% [markdown]
# ## Errores (excepciones)

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-562903200.py in <cell line: 0>()
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
try:
  dividendo = float(input("Ingresa el dividendo: "))
  divisor = float(input("Ingresa el divisor: "))
  division = dividendo / divisor
except ZeroDivisionError:
  print("Error: El divisor no debe de ser 0")
# Out:
# Ingresa el dividendo: 9
# Ingresa el divisor: 0
# Error: El divisor no debe de ser 0

# %%
#Tenemos otros tipos de errores, por ejemplo, el de ValueError que sale al ingresar el tipo incorrecto de dato#Digamos que un usuario ingresa texto en un lugar de un número, esto nos ayuda a manejarlo

try:
  numero = int(input("Escriba un numero: "))
  print(numero)
except ValueError:
  print("Error: Ingrese un valor numerico")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3327019202.py in <cell line: 0>()
#       2
#       3 try:
# ----> 4   numero = int(input("Escriba un numero: "))
#       5   print(numero)
#       6 except ValueError:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Tambien podemos manejar mas de una excepcion, por ejemplo con la division podemos tener tanto el tipo de valor como el de la division entre 0
try:
  dividendo = float(input("Ingresa el dividendo: "))
  divisor = float(input("Ingresa el divisor: "))
  division = dividendo / divisor
except ZeroDivisionError:
  print("Error: El divisor no debe de ser 0")
except ValueError:
  print("Error: Ingrese un valor numerico")
# Out:
# Ingresa el dividendo: 9
# Ingresa el divisor: p
# Error: Ingrese un valor numerico

# %%
def promediosYmayor(promedios):promedio = 0for x in promedios:promedio += xpromedio = promedio/len(promedios)return promedio, max(promedios)promedios = []continuar = ""while True:if len(promedios) > 0:continuar=""while continuar not in ("si", "no"):continuar = input("Ingrese una respuesta válida: si/no").lower()if continuar == "no":breakwhile True:try:calif = int(input("Indique la calificación: "))if calif < 0 or calif > 100:print("Ingrese un valor valido")else:promedios.append(calif)breakexcept ValueError:print("Ingrese un valor numérico")prom, mayor = promediosYmayor(promedios)print("\nResultados:")print("Promedio:", prom)print("Mayor:", mayor)

# %%
# Calculadora -> suma, resta, producto, division y potencia
def suma(a, b):
    return a + b

def resta(a, b):
    return a - b

def producto(a, b):
    return a * b

def division(a, b):
    if b == 0:
        return "Error: no se puede dividir entre 0"
    return a / b

def potencia(a, b):
    return a ** b

def menu():
    print("-------- MI CALCULADORA --------")
    print("1. Suma")
    print("2. Resta")
    print("3. Producto")
    print("4. División")
    print("5. Potencia")
    print("6. Salir")

while True:
    menu()
    try:
        op = int(input("Seleccione una opción: "))
    except ValueError:
        print("Ingrese un número válido")
        continue

    if op == 6:
        print("SALIENDO...")
        break

    if op < 1 or op > 6:
        print("Opción inválida")
        continue

    try:
        a = float(input("Ingrese el primer número: "))
        b = float(input("Ingrese el segundo número: "))
    except ValueError:
        print("Error: Ingrese un número válido")
        continue

    if op == 1:
        print("Resultado:", suma(a, b))
    elif op == 2:
        print("Resultado:", resta(a, b))
    elif op == 3:
        print("Resultado:", producto(a, b))
    elif op == 4:
        print("Resultado:", division(a, b))
    elif op == 5:
        print("Resultado:", potencia(a, b))
# Out:
# -------- MI CALCULADORA --------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# Seleccione una opción: 6
# SALIENDO...
