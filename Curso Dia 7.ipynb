# %% [markdown]
# # DIA 7
# ## TEMARIO
#   - Manipulacion de datos
#   - Limpieza de datos'
#   - Introduccion a la regresion lineal

# %% [markdown]
# ## Datos

# %%
import pandas as pd
import numpy as np

# %%
data = {"nombre": ["Ana", "Juan", "Pedro", "Maria", "Luis", None],
        "edad": [23, 35, None, 29, 41, 30],
        "ciudad": ["CDMX", "cdmx", "Monterrey ", "GDL", "  gdl", "CDMX"],
        "ingresos": ["$12,000", "$18,500", "$15,300", None, "$22000.", "$17800."]}

# %% [markdown]
# ## Manipulacion de datos

# %%
# nota: para importar un .csv se usa el:
#variable = pd.read_csv("NombreArchivo.csv")
df = pd.DataFrame(data)
df
# Out:
#   nombre  edad      ciudad ingresos
# 0    Ana  23.0        CDMX  $12,000
# 1   Juan  35.0        cdmx  $18,500
# 2  Pedro   NaN  Monterrey   $15,300
# 3  Maria  29.0         GDL     None
# 4   Luis  41.0         gdl  $22000.
# 5   None  30.0        CDMX  $17800.

# %% [markdown]
# ## Que es un dataframe?
# Es una tabla de datos: filas (registros) y columnas (variables).

# %%
# Exploracion de los datos
df.head()
# Out:
#   nombre  edad      ciudad ingresos
# 0    Ana  23.0        CDMX  $12,000
# 1   Juan  35.0        cdmx  $18,500
# 2  Pedro   NaN  Monterrey   $15,300
# 3  Maria  29.0         GDL     None
# 4   Luis  41.0         gdl  $22000.

# %%
# Si deseas ver las columnas  puedes hacerlo con
df.columns
# Out:
# Index(['nombre', 'edad', 'ciudad', 'ingresos'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    5 non-null      object
#  1   edad      5 non-null      float64
#  2   ciudad    6 non-null      object
#  3   ingresos  5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 324.0+ bytes

# %%
df.describe(include="all") # te da una mera descripcion de todo
# Out:
#        nombre      edad ciudad ingresos
# count       5   5.00000      6        5
# unique      5       NaN      5        5
# top       Ana       NaN   CDMX  $12,000
# freq        1       NaN      2        1
# mean      NaN  31.60000    NaN      NaN
# std       NaN   6.76757    NaN      NaN
# min       NaN  23.00000    NaN      NaN
# 25%       NaN  29.00000    NaN      NaN
# 50%       NaN  30.00000    NaN      NaN
# 75%       NaN  35.00000    NaN      NaN
# max       NaN  41.00000    NaN      NaN

# %%
df.columns
# Out:
# Index(['nombre', 'edad', 'ciudad', 'ingresos'], dtype='object')

# %%
df["edad"]
# Out:
# 0    23.0
# 1    35.0
# 2     NaN
# 3    29.0
# 4    41.0
# 5    30.0
# Name: edad, dtype: float64

# %%
df[df["edad"]>30]
# Out:
#   nombre  edad ciudad ingresos
# 1   Juan  35.0   cdmx  $18,500
# 4   Luis  41.0    gdl  $22000.

# %%
print(df)
df[
   (df["edad"] > 18) &
   (df["ingresos"] != "$22000") &
   (df["nombre"] != "Juan")

]
# Out:
#   nombre  edad      ciudad ingresos
# 0    Ana  23.0        CDMX  $12,000
# 1   Juan  35.0        cdmx  $18,500
# 2  Pedro   NaN  Monterrey   $15,300
# 3  Maria  29.0         GDL     None
# 4   Luis  41.0         gdl  $22000.
# 5   None  30.0        CDMX  $17800.
#   nombre  edad ciudad ingresos
# 0    Ana  23.0   CDMX  $12,000
# 3  Maria  29.0    GDL     None
# 4   Luis  41.0    gdl  $22000.
# 5   None  30.0   CDMX  $17800.

# %%
# Uso de count(), mean(), sum(), fillna(), str.replace(), astype()
print(df["edad"].count()) # Son 6 pero 1 es none
print("----------")
print(df["edad"].mean()) # Promedio de edades
print("----------")
print(df["edad"].sum()) # Suma de edades
print("----------")
print(df["nombre"].fillna("Desconocido")) # Reemplaza los valores nulos por algo en especifico
print("----------")
print(df["ingresos"].str.replace("$", "").str.replace(",","").astype(float)) # Reemplaza x simbolo por y
# .astype(tipo_de_dato) cambia el tipo de dato de tu columna
# Out:
# 5
# ----------
# 31.6
# ----------
# 158.0
# ----------
# 0            Ana
# 1           Juan
# 2          Pedro
# 3          Maria
# 4           Luis
# 5    Desconocido
# Name: nombre, dtype: object
# ----------
# 0    12000.0
# 1    18500.0
# 2    15300.0
# 3        NaN
# 4    22000.0
# 5    17800.0
# Name: ingresos, dtype: float64

# %% [markdown]
# ## LIMPIEZA DE DATOS

# %%
df_clean = df.copy()
df_clean
# Rellenar valores faltantes
df_clean["edad"] = df_clean["edad"].fillna(df_clean["edad"].mean())
df_clean["ingresos"] = df_clean["ingresos"].fillna("$0")
df_clean["nombre"] = df_clean["nombre"].fillna("Desconocido")
df_clean
# Out:
#         nombre  edad      ciudad ingresos
# 0          Ana  23.0        CDMX  $12,000
# 1         Juan  35.0        cdmx  $18,500
# 2        Pedro  31.6  Monterrey   $15,300
# 3        Maria  29.0         GDL       $0
# 4         Luis  41.0         gdl  $22000.
# 5  Desconocido  30.0        CDMX  $17800.

# %%
df_clean["ciudad"] = (
    df_clean["ciudad"]
    .str.strip() # Todo en minusculas, para mayusculas es upper
    .str.lower() # Para quitar espacios
)
df_clean
# Out:
#         nombre  edad     ciudad ingresos
# 0          Ana  23.0       cdmx  $12,000
# 1         Juan  35.0       cdmx  $18,500
# 2        Pedro  31.6  monterrey  $15,300
# 3        Maria  29.0        gdl       $0
# 4         Luis  41.0        gdl  $22000.
# 5  Desconocido  30.0       cdmx  $17800.

# %%
# Ahora con los datos limpios podemos trabajar con ellos
# Ejercicio rapido
# 1) Saca los nombres de todos
# 2) Saca los nombres de todos los que digan desconocidos
# 3) Saca la cantidad de personas que hay por medio de ciudad
# Ahora pondremos uno un poco mas dificil
# 4) Saca todos los datos donde no se muestre "Desconocido". donde no se muestre los que son de monterrey en ciudad, y donde no se muestren los ingresos que sean $0
# 5) Saca la edad promedio de las personas que no son de monterrey que ganan mayor o igual que $10,000


# 1)
df_clean["nombre"]

# %%
# 2)
df_clean[df_clean["nombre"] != "Desconocido"]["nombre"]
# Out:
# 0      Ana
# 1     Juan
# 2    Pedro
# 3    Maria
# 4     Luis
# Name: nombre, dtype: object

# %%
# 3)
df_clean["ciudad"].count()
# Out:
# np.int64(6)

# %%
# 4)
df_clean[(df_clean["nombre"] != "Desconocido") & (df_clean["ciudad"] != "monterrey") & (df_clean["ingresos"] != "$0")]
# Out:
#   nombre  edad ciudad ingresos
# 0    Ana  23.0   cdmx  $12,000
# 1   Juan  35.0   cdmx  $18,500
# 4   Luis  41.0    gdl  $22000.

# %%
# 5)
df_clean[(df_clean["ciudad"] != "cdmx") & (df_clean["ingresos"] != "$10,000")]["edad"].mean()
# Out:
# np.float64(33.86666666666667)

# %%
# Limpiemos una ultima vez el dataframe inicial para iniciar con la regresion lineal
df_clean["ingresos"] = df_clean["ingresos"].fillna("$0")
df_clean["ingresos"] = df["ingresos"].str.replace("$", "").str.replace(",","").astype(float)
df_clean
# Out:
#         nombre  edad     ciudad  ingresos
# 0          Ana  23.0       cdmx   12000.0
# 1         Juan  35.0       cdmx   18500.0
# 2        Pedro  31.6  monterrey   15300.0
# 3        Maria  29.0        gdl       NaN
# 4         Luis  41.0        gdl   22000.0
# 5  Desconocido  30.0       cdmx   17800.0

# %%
df_clean["ingresos"] = (
    df["ingresos"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
    .fillna(0)
)

print(df_clean)
# Out:
#         nombre  edad     ciudad  ingresos
# 0          Ana  23.0       cdmx   12000.0
# 1         Juan  35.0       cdmx   18500.0
# 2        Pedro  31.6  monterrey   15300.0
# 3        Maria  29.0        gdl       0.0
# 4         Luis  41.0        gdl   22000.0
# 5  Desconocido  30.0       cdmx   17800.0

# %% [markdown]
# ## Introduccion a la regresion lineal

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Que es una regresion lineal?
# Una regresion intenta predecir un valor numerico a partir de otros datos
#
# Ejemplo:
# - Predecir ingresos segun edad
# - Predecir precios segun tamaño
#
# Aqui usaremos regresion lineal: el tipo mas simple

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x = df_clean["edad"], y = df_clean["ingresos"])
plt.xlabel("Edad")
plt.ylabel("Ingresos")
plt.title("Relacion entre edad e ingresos")
plt.show()

# %%
# MATRIZ DE CORRELACION
# df_clean.corr()
df_clean[["edad", "ingresos"]].corr()

# 0.0 -> nada
# 0.3 -> debil
# 0.5 - 0.7 -> moderada
# > 0.8 -> fuerte
# Out:
#               edad  ingresos
# edad      1.000000  0.588779
# ingresos  0.588779  1.000000

# %%
x = df_clean[["edad"]]
y = df_clean["ingresos"]
modelo = LinearRegression()
modelo.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# Tiene relacion con la formula de la pendiente
# Que hace fit? Busca los valores de m, y b que mejor se ajustan a tus datos.
# Minimiza el error entre los ingresos reales y los ingresos predichos.

# %%
edad_nueva = [[30]]
prediccion = modelo.predict(edad_nueva)
prediccion
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13061.25181951])

# %%
# Podemos evaluar el modelo
from sklearn.metrics import mean_squared_error, r2_score
y_pred = modelo.predict(x) # Son los ingresos que el modelo cree segun la edad
#ingresos = β0 + β1 · edad
#β0 → intercepto
#β1 → coeficiente de edad

r2 = r2_score(y, y_pred)
# 0.3 - 0.5  es aceptable, pero siempre es mejor tener un modelo entre 0.6 - 0.8, o superior
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
print(r2)

# Regresion logistica se suele usar -> Accuracy, F1 Score, Recall, Roc Auc
# Out:
# 0.34666091920946085
